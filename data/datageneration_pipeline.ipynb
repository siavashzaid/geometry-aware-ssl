# %% [markdown]
# <h3> Imports

# %%
import sys
sys.path.append("../src")
from acoupipe_extensions import VariableArrayConfig, random_positions, VogelHansen

from acoupipe.datasets.synthetic import DatasetSynthetic
import numpy as np
# Out:
# /home/zaid/.conda/envs/thesis/lib/python3.12/site-packages/numba/np/ufunc/parallel.py:373: NumbaWarning: The TBB threading layer requires TBB version 2021 update 6 or later i.e., TBB_INTERFACE_VERSION >= 12060. Found TBB_INTERFACE_VERSION = 12050. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %% [markdown]
# <h3> Main Data Generation Pipeline

# %%
# --- generate config for dataset ---
test_generator = np.random.default_rng(seed=300)
config = VariableArrayConfig(mpos_fn=VogelHansen, mode="analytic", mic_sig_noise=False, generator=test_generator, min_nsources=1, max_nsources=4, min_num_mics=32, max_num_mics=32)

# --- generate dataset and save to .h5 file ---
d1 = DatasetSynthetic(config=config)

d1.save_h5(features=["csm", "cartesian_coordinates", "eigmode", "loc", 'source_strength_analytic' ], f=2500, num=0, split="training", size=10000, name="10k_32to64_test.h5")
# Out:
# /home/zaid/.conda/envs/thesis/lib/python3.12/site-packages/acoupipe/datasets/features.py:225: Warning: Queried frequency (2500 Hz) not in set of discrete FFT sample frequencies. Using frequency 2572.5 Hz instead.
#   fidx = [get_frequency_index_range(self.freq_data.fftfreq(), f_, self.num) for f_ in f]
#  43%|████▎     | 4345/10000 [02:56<04:08, 22.75it/s]/mnt/data/zaid/projects/geometry-aware-ssl/data/../src/acoupipe_extensions.py:203: RuntimeWarning: Number of calls to function has reached maxfev = 6600.
#   rz = optimize.leastsq(Froot,np.zeros(M)/M+0.01)
# 100%|██████████| 10000/10000 [06:45<00:00, 24.68it/s]
