# %% [markdown]
# <h3> Imports

# %%
import sys
sys.path.append("../src")
from acoupipe_extensions import VariableArrayConfig, random_positions, VogelHansen

from acoupipe.datasets.synthetic import DatasetSynthetic
import numpy as np
# Out:
# /home/zaid/.conda/envs/thesis/lib/python3.12/site-packages/numba/np/ufunc/parallel.py:373: NumbaWarning: The TBB threading layer requires TBB version 2021 update 6 or later i.e., TBB_INTERFACE_VERSION >= 12060. Found TBB_INTERFACE_VERSION = 12050. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %% [markdown]
# <h3> Main Data Generation Pipeline

# %%
# --- generate config for dataset ---
test_generator = np.random.default_rng(seed=600)
config = VariableArrayConfig(mpos_fn=VogelHansen, mode="analytic", mic_sig_noise=False, generator=test_generator, min_nsources=1, max_nsources=4, min_num_mics=32, max_num_mics=64)

# --- generate dataset and save to .h5 file ---
d1 = DatasetSynthetic(config=config)

d1.save_h5(features=["csm", "cartesian_coordinates", "eigmode", "loc", 'source_strength_analytic' ], f=2500, num=0, split="training", size=62500, name="validation.h5")
# Out:
#   2%|▏         | 1040/62500 [00:58<1:05:25, 15.66it/s]/mnt/data/zaid/projects/geometry-aware-ssl/data/../src/acoupipe_extensions.py:199: RuntimeWarning: Number of calls to function has reached maxfev = 9800.
#   rz = optimize.leastsq(Froot,np.zeros(M)/M+0.01)
#   4%|▍         | 2452/62500 [02:22<1:06:49, 14.98it/s]/mnt/data/zaid/projects/geometry-aware-ssl/data/../src/acoupipe_extensions.py:199: RuntimeWarning: Number of calls to function has reached maxfev = 12800.
#   rz = optimize.leastsq(Froot,np.zeros(M)/M+0.01)
#   5%|▍         | 2960/62500 [02:51<1:24:00, 11.81it/s]/mnt/data/zaid/projects/geometry-aware-ssl/data/../src/acoupipe_extensions.py:199: RuntimeWarning: Number of calls to function has reached maxfev = 8000.
#   rz = optimize.leastsq(Froot,np.zeros(M)/M+0.01)
#   8%|▊         | 4817/62500 [04:40<46:49, 20.53it/s]  /mnt/data/zaid/projects/geometry-aware-ssl/data/../src/acoupipe_extensions.py:199: RuntimeWarning: Number of calls to function has reached maxfev = 11200.
# ...
